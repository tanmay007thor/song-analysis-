# %%
import pandas as pd
import numpy as np

actual_data = pd.read_csv('../data/light_spotify_dataset.csv')  
preprocessed_data = pd.read_csv('../data/preprocess.csv')  
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity


data = pd.read_csv('../data/preprocess.csv')


autoencoder = tf.keras.models.load_model('../model/song_autoencoder_model.h5', compile=False)


encoder = tf.keras.models.Model(inputs=autoencoder.input, outputs=autoencoder.get_layer('dense_6').output)


features = [
    'variance', 'Tempo', 'Loudness', 'Explicit', 'Popularity', 'Energy',
    'Danceability', 'Positiveness', 'Speechiness', 'Liveness',
    'Acousticness', 'Instrumentalness'
]

scaler = StandardScaler()
X = scaler.fit_transform(data[features])


def get_song_recommendations(song_name, top_n=20):
    song_name = song_name.strip().lower()  
    data['normalized_song_name'] = data['song name'].str.strip().str.lower()  
    
    
    if song_name not in data['normalized_song_name'].values:
        raise ValueError(f"Song '{song_name}' not found in the dataset.")
    
    
    song_index = data[data['normalized_song_name'] == song_name].index[0]
    
    
    song_encoded = encoder.predict(X[song_index].reshape(1, -1))
    
    
    encoded_features = encoder.predict(X)
    
    
    similarities = cosine_similarity(song_encoded, encoded_features)
    
    
    similar_song_indices = similarities[0].argsort()[-top_n-1:-1][::-1]
    
    
    similar_songs = data.iloc[similar_song_indices][['song name', 'artist name']]
    similar_songs['Similarity'] = similarities[0][similar_song_indices]
    
    return similar_songs


song_name_input = "mockingbird"
try:
    recommendations = get_song_recommendations(song_name_input, top_n=20)
    print(recommendations)
except ValueError as e:
    print(e)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 7406/7406 ━━━━━━━━━━━━━━━━━━━━ 6s 751us/step
#                                   song name           artist name  Similarity
# 2409                     One Million Kisses            Chaka Khan    0.999797
# 18768                            Shangri-la     Steve Miller Band    0.999787
# 7041                          If You Got It      Gordon Lightfoot    0.999660
# 10133      Unless The Lord Builds The House           Keith Green    0.999605
# 9053                              Night Owl          James Taylor    0.999587
# 55341                             True Love            Wang Chung    0.999532
# 2175                           Is This Love           Carly Simon    0.999487
# 18804  Come Let Me Make Your Love Come Down         Stevie Wonder    0.999472
# 55534                                 Alone       Waylon Jennings    0.999377
# 28807                         What Can I Do       David Allan Coe    0.999333
# 51224                           Summer Lady               Santana    0.999261
# 23224                  Too Close To The Sun  Alan Parsons Project    0.999198
# 39455                     When There's Love           Keith Green    0.999183
# 11829                   Deep As Your Pocket          Loretta Lynn    0.999141
# 15034                         Demonstration          Otis Redding    0.999133
# 17200                       One Good Reason         Reba Mcentire    0.999046
# 44649                        Deck The Halls         Nat King Cole    0.998979
# 1575                When The Cows Come Home                  Blur    0.998936
# 19260                   Welcome To The Club            Tim McGraw    0.998916
# 11915            I've Got Texas In My Heart          Loretta Lynn    0.998876

# %%
def get_song_recommendations(song_name, top_n=20):
    
    song_name = song_name.strip().lower()
    
    
    data['normalized_song_name'] = data['song name'].str.strip().str.lower()
    
    
    if song_name not in data['normalized_song_name'].values:
        raise ValueError(f"Song '{song_name}' not found in the dataset.")
    
    
    song_index = data[data['normalized_song_name'] == song_name].index[0]
    
    
    song_encoded = encoder.predict(X[song_index].reshape(1, -1))
    
    
    encoded_features = encoder.predict(X)
    
    
    similarities = cosine_similarity(song_encoded, encoded_features)
    
    
    similar_song_indices = similarities[0].argsort()[-top_n-1:-1][::-1]
    
    
    similar_songs = data.iloc[similar_song_indices][['song name', 'artist name']]
    similar_songs['Similarity'] = similarities[0][similar_song_indices]
    
    return similar_songs


song_name_input = "Chemical Warfare"  
try:
    recommendations = get_song_recommendations(song_name_input, top_n=20)
    print(recommendations)
except ValueError as e:
    print(e)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 7406/7406 ━━━━━━━━━━━━━━━━━━━━ 5s 648us/step
#                                  song name               artist name  \
# 46209                     B.I.G. Interlude          Notorious B.I.G.
# 45629                  Can Anybody Hear Me               Nicki Minaj
# 51703                      Gangsta Like Me                Snoop Dogg
# 56922                                Klack                    Xzibit
# 5675                 Don't Stop Won't Stop                  Fabolous
# 49752                           I'm Housin  Rage Against The Machine
# 57348                          Bury Me A G               Young Jeezy
# 36921                        Scatter Brain        Insane Clown Posse
# 56912                           Cold World                    Xzibit
# 40066                           In So Deep                  Kid Rock
# 56641                                Maria              Wu-Tang Clan
# 51690                           Doggfather                Snoop Dogg
# 8495   Intro (Forgotten Freshness, Vol. 3)        Insane Clown Posse
# 21960                  Put That Thang Down           Ying Yang Twins
# 15200                    Myintrotoletuknow                   Outkast
# 21634                          In The Hood              Wu-Tang Clan
# 8055                What They Hittin' Foe?                  Ice Cube
# 36886                               Juggla        Insane Clown Posse
# 21949               Bicken Back Being Bool                        YG
# 51695                           Don't Stop                Snoop Dogg
#
#        Similarity
# 46209    0.997729
# 45629    0.996899
# 51703    0.995885
# 56922    0.994640
# 5675     0.994462
# 49752    0.993924
# 57348    0.993808
# 36921    0.993204
# 56912    0.993076
# 40066    0.993056
# 56641    0.992914
# 51690    0.992175
# 8495     0.992091
# 21960    0.991758
# 15200    0.991590
# 21634    0.991310
# 8055     0.991287
# 36886    0.991128
# 21949    0.991105
# 51695    0.991066
